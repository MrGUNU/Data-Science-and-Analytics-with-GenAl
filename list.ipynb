# %%
# Question 1
a = [10, 20, 30, 40, 50]
sum = 0

for i in a:
    sum = sum + i
print(sum)
print(sum/len(a))
# Out:
# 150
# 30.0

# %%
# Question 2
a = [1,23,54,45,67,78,90,55,78,70]

max = a[0]
index = 0

for i in range(len(a)):
    if a[i] > max:
        max = a[i]
        index = i

print(max)
print(index)
# Out:
# 90
# 6

# %%
# Question 3
a = [1,23,54,45,67,78,90,55,78,70]

max = a[0]
max2 = a[0]
index = 0
index2 = 0

for i in range(len(a)):
    if a[i] > max:
        max2 = max
        max = a[i]
        index2 = index
        index = i

print(max)
print(index)
print(max2)
print(index2)
# Out:
# 90
# 6
# 78
# 5
